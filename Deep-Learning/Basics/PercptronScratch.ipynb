# %%
# Genrative datasets
from sklearn.datasets import make_classification
X,y=make_classification(
    n_samples=200,
    n_classes=2,
    n_redundant=0,
    n_informative=2,
    n_clusters_per_class=2
)

# %%
#  Activation function
import numpy as np
y=np.where(y==0,-1,1)
print(np.unique(y))
# Out:
# [-1  1]

# %%
# Number of features
n_samples , n_features = X.shape

# %%
# Initialize weights randomely
weight=np.random.randn(n_features)

# %%
# Initialize Bias
bias=0

# %%
print("Weights",weight)
print("Bias",bias)
# Out:
# Weights [-0.34975547 -0.14352588  0.75847553 -1.12974933  1.18537401  0.7832681
#   0.72304415  1.75833179 -0.24382756  0.22437821 -0.40037269  0.57457098
#   1.8550938  -0.68738884  1.32615978  1.73492533 -0.02790954 -1.83189106
#  -0.97138167  0.20917589]
# Bias 0
